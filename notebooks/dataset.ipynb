# %%
import os
import sys
from datetime import datetime

import pandas as pd

root = os.path.abspath('../')
if root not in sys.path:
    sys.path.append(root)
    
from model.data import load_pic, get_patient_records
from model.featurization import generate_cutoff_times

# %%
es = load_pic(verbose=False)

# %%
cutoff_times = generate_cutoff_times(es)

# %%
get_patient_records(es, 'SURGERY_VITAL_SIGNS', 3718, cutoff_times=cutoff_times)
# Out:
#          ITEM_NO        MONITOR_TIME ITEMID  VALUE
# 1695378        1 2067-05-10 18:25:00    SV1  151.0
# 1695379        1 2067-05-10 18:25:00    SV2  151.0
# 1695380        1 2067-05-10 18:25:00   SV17   98.0
# 1695390        2 2067-05-10 18:30:00    SV1  137.0
# 1695391        2 2067-05-10 18:30:00    SV2  139.0
# ...          ...                 ...    ...    ...
# 1695688       32 2067-05-10 20:55:00    SV4   41.0
# 1695689       32 2067-05-10 20:55:00    SV6    6.0
# 1695690       32 2067-05-10 20:55:00   SV13   26.0
# 1695691       32 2067-05-10 20:55:00   SV16   35.0
# 1695692       32 2067-05-10 20:55:00    SV5   62.0
#
# [315 rows x 4 columns]

# %%
get_patient_records(es, 'INPUTEVENTS', 3718, cutoff_times=cutoff_times)
# Out:
#                CHARTTIME  AMOUNT AMOUNTUOM           STORETIME
# 2317 2065-11-02 07:27:18   413.0        ml 2065-11-02 07:27:18
# 2279 2065-11-03 07:29:56   398.0        ml 2065-11-03 07:29:56
# 1907 2065-11-04 07:48:34   426.0        ml 2065-11-04 07:48:34
# 2036 2065-11-09 07:05:09   420.0        ml 2065-11-09 07:05:09
# 2146 2065-11-24 06:28:46   420.0        ml 2065-11-24 06:28:46

# %%
get_patient_records(es, 'SURGERY_INFO', 3718, cutoff_times=cutoff_times)
# Out:
#            ANES_START_TIME       ANES_END_TIME  SURGERY_BEGIN_TIME  \
# 429001 2067-05-10 18:30:00 2067-05-10 21:08:00 2067-05-10 19:11:00
#
#           SURGERY_END_TIME SURGERY_NAME  \
# 429001 2067-05-10 20:55:00   ASD repair
#
#                                               ANES_METHOD SURGERY_POSITION  \
# 429001  general anesthesia with endotracheal intubatio...  supine position
#
#         Height  Weight  Preoperative oxygen saturation (%)  ...  \
# 429001    80.0     9.2                               100.0  ...
#
#         Surgical time (minutes)  CPB time (minutes)  \
# 429001                      102                49.0
#
#         Aortic cross-clamping time (times)  complication  lung complication  \
# 429001                                29.0             0                  0
#
#         cardiac complication  arrhythmia complication  \
# 429001                     0                        0
#
#         infectious complication  other complication  Age
# ...

# %%
get_patient_records(es, 'ADMISSIONS', 3718, cutoff_times=cutoff_times)
# Out:
#                  ADMITTIME           DISCHTIME DEATHTIME  \
# 103784 2065-10-15 16:30:55 2065-11-25 12:25:00       NaT
# 106703 2067-05-07 15:42:22 2067-05-17 09:29:00       NaT
#
#               ADMISSION_DEPARTMENT        DISCHARGE_DEPARTMENT  \
# 103784                        NICU                        NICU
# 106703  Cardiac surgery department  Cardiac surgery department
#
#                 INSURANCE LANGUAGE       RELIGION MARITAL_STATUS   ETHNICITY  \
# 103784  Medical Insurance      CHN  Not specified         Single  Han ethnic
# 106703  Medical Insurance      CHN  Not specified         Single  Han ethnic
#
#                  EDREGTIME           EDOUTTIME DIAGNOSIS ICD10_CODE_CN  \
# 103784 2065-10-15 16:30:55 2065-11-25 12:25:00    早产不伴分娩       O60.000
# 106703 2067-05-07 15:42:22 2067-05-17 09:29:00     房间隔缺损       Q21.100
#
#         HOSPITAL_EXPIRE_FLAG  HAS_CHARTEVENTS_DATA
# 103784                     0                     1
# ...
